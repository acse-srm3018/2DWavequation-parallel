# %%
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(20, 8))
ax1 = fig.add_subplot(121)

nodes = [1, 4, 8, 16, 32, 64]
time_elapsed_10 = [0.23, 0.09, 0.054, 0.015, 0.025, 0.036]
speedup_100 = [19.65/19.65, 19.65/9.02017, 19.65/5.718, 19.65/2.619, 19.65/1.548, 19.65/0.641]
speedup_200 = [65.23/65.23, 65.23/14.378, 65.23/9.432, 65.23/4.916, 65.23/2.6583, 65.23/1.4047]
speedup_500 = [1071.21/1071.21, 1071.21/310.056, 1071.21/151.54, 1071.21/76.428, 1071.21/35.2675, 1071.21/19.307]
speedup_1000 = [1500/1500, 1500/932.65, 1500/190.23, 1500/69.91, 1500/37.619, 1500/19.25]
#plt.plot(nodes, time_elapsed_10, label='10 * 10')
ax1.plot(nodes, speedup_100, 'ro-', label='100 * 100')
ax1.plot(nodes, speedup_200,'bo-',  label='200 * 200')
ax1.plot(nodes, speedup_500, 'go-', label='500 * 500')
ax1.plot(nodes, speedup_1000, 'ko-',label='1000 * 1000')
#ax1.gca().legend(('100*100', '200*200', '500*500', '1000*1000'))

ax1.set_xlabel('$Cores$')
ax1.set_ylabel('$Speed up$')
ax1.set_title('$Speed up$')
plt.savefig('speedup.png')
#ax1.set_title('Initial condition', fontsize=14);
#ax1.set_xlim(0, Lx)
#ax1.set_ylim(0, Ly)

# %%
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(121)

nodes = [1, 4, 8, 16, 32, 64]
nodes1 = [1,8,16,32,64]
speedup_100 = [19.65/19.65, 19.65/9.02017/4, 19.65/5.718/8, 19.65/2.619/16, 19.65/1.548/32, 19.65/0.641/64]
speedup_200 = [65.23/65.23, 65.23/14.378/4, 65.23/9.432/8, 65.23/4.916/16, 65.23/2.6583/32, 65.23/1.4047/64]
speedup_500 = [1071.21/1071.21, 1071.21/310.056/4, 1071.21/151.54/8, 1071.21/76.428/16, 1071.21/35.2675/32, 1071.21/19.307/64]
speedup_1000 = [1000/1000, 1000/200.4/4, 1000/120.23/8, 1000/69.91/16, 1000/37.619/32, 1000/19.25/64]
#plt.plot(nodes, time_elapsed_10, label='10 * 10')
ax1.plot(nodes, speedup_200, 'bo--', label='200 * 200')
ax1.plot(nodes, speedup_500, 'ro-', label='500 * 500')
ax1.plot(nodes, speedup_1000, 'go-', label='1000 * 1000')
#lt.gca().legend(('200*200', '500*500', '1000*1000'))

ax1.set_xlabel('$Cores$')
ax1.set_ylabel('$Parallel efficiency$')
#ax1.savefig('prallelefficiency.png')

#ax1.set_title('Initial condition', fontsize=14);
#ax1.set_xlim(0, Lx)
#ax1.set_ylim(0, Ly)
# Out:
# Text(0, 0.5, '$Parallel efficiency$')
